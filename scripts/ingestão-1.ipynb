# %%
import duckdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import duckdb
#
# ModuleNotFoundError: No module named 'duckdb'

# %%
import sys

# %%
print(sys.executable)
# Out:
# d:\Rebecca\ANACONDA\python.exe

# %%
import duckdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import duckdb
#
# ModuleNotFoundError: No module named 'duckdb'

# %%
import sys
print(sys.executable)
# Out:
# d:\Rebecca\ANACONDA\python.exe

# %%
import sys 
# !{sys.executable} -m pip install duckdb
# Out:
# Requirement already satisfied: duckdb in d:\rebecca\anaconda\lib\site-packages (1.4.4)

# %%
import duckdb

# %%
import duckdb
import pandas as pd
import os
from datetime import datetime

# %%
con = duckdb.connect(database='dados_duckdb.db', read_only=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 con = duckdb.connect(database='dados_duckdb.db', read_only=False)
#
# NameError: name 'duckdb' is not defined

# %%
import duckdb
con = duckdb.connect(database='dados_duckdb.db', read_only=False)

# %%
import pandas as pd
from datetime import datetime
arquivo = 'z0019_2.csv'
data_ingestão = datetime.now()
df = pd.read_csv(f'..\landing\{arquivo}', sep = ';')
df['nome_arquivo'] = arquivo
df['data_ingestão'] = data_ingestão
df.head()
# Out:
#    NATBR    MAKTX WERKS  MAINS  LABST nome_arquivo              data_ingestão
# 0   1004    SERRA  BT50    100    200  z0019_2.csv 2026-02-17 08:09:59.307653
# 1   1005  MACHADO  BT50    100    100  z0019_2.csv 2026-02-17 08:09:59.307653
# 2   1003    PREGO  BT10    100     60  z0019_2.csv 2026-02-17 08:09:59.307653

# %%
con.execute("""
Create table if not exists bronze_produtos(
            NATBR VARCHAR,
            MAKTX VARCHAR,
            WERKS VARCHAR,
            MAINS VARCHAR,
            LABST VARCHAR,
            nome_arquivo VARCHAR,
            data_ingestão TIMESTAMP
            )
""")

# %%
con.execute("insert into bronze_produtos select * from df")

# %%
resultado = con.execute("SELECT * FROM bronze_z0019").fetchdf()
resultado.head()
# Out:
#   NATBR     MAKTX WERKS MAINS LABST nome_arquivo              data_ingestão
# 0  1001  PARAFUSO  BT10   100   100  z0019_1.csv 2026-02-17 07:01:04.013625
# 1  1002   MARTELO  BT50   100  1500  z0019_1.csv 2026-02-17 07:01:04.013625
# 2  1003     PREGO  BT10   100    50  z0019_1.csv 2026-02-17 07:01:04.013625
# 3  1004     SERRA  BT50   100   200  z0019_2.csv 2026-02-17 08:09:59.307653
# 4  1005   MACHADO  BT50   100   100  z0019_2.csv 2026-02-17 08:09:59.307653

# %%
con.execute("ALTER table bronze_produtos RENAME to bronze_z0019")

# %%
con.close()
